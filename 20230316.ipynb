# %% [markdown]
# <a href="https://colab.research.google.com/github/WooJungE/About_data/blob/main/20230316.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
y = [1, 2 ,3, 4, 5]
plt.plot(y)
plt.show()

# %%
y=[13, 16, 15, 18, 16, 17, 16]
plt.plot(range(len(y)), y);

# %%
x = ['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun']
y=[13, 16, 15, 18, 16, 17, 16]
plt.plot(x,y);

# %%
x = ['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun']
y=[13, 16, 15, 18, 16, 17, 16]
plt.plot(x,y);
plt.xlabel('Daily')
plt.ylabel('No. of Books Sold')
# Out:
# Text(0, 0.5, 'No. of Books Sold')

# %%
x = ['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun']
y1=[13, 16, 15, 18, 16, 17, 16]
y2=[17, 14, 17, 16, 15, 15, 14]
plt.plot(x,y1);
plt.plot(x,y2);
plt.xlabel('Daily')
plt.ylabel('No. of Books Sold');

# %%
x = ['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun']
y1=[13, 16, 15, 18, 16, 17, 16]
y2=[17, 14, 17, 16, 15, 15, 14]
plt.plot(x,y1, label='Sold');
plt.plot(x,y2, label='On Shelves')
plt.xlabel('Daily')
plt.ylabel('No. of Books Sold')
plt.legend(loc="upper left")

# %%
x = ['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun']
y1=[13, 16, 15, 18, 16, 17, 16]
y2=[17, 14, 17, 16, 15, 15, 14]
plt.plot(x,y1);
plt.plot(x,y2);
plt.xlabel('Daily')
plt.ylabel('No. of Books Sold');
plt.legend(loc="upper left")
plt.title('Le Petit Prince: Sold & Left')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 1.0, 'Le Petit Prince: Sold & Left')

# %%
x=[1, 2, 3, 4, 5]
y=[1, 4, 9, 16, 25]
plt.plot(x, y, 'bo')
plt.show()

# %%
x=[1, 2, 3, 4, 5]
y=[1, 4, 9, 16, 25]
plt.plot(x, y, 'bo')
plt.axis([0, 6, 0, 30])
plt.show()

# %%
import numpy as np
points = np.array([[1,1], [1,2], [1,3], [2,1], [2,2], [2,3], [3,1], [3,2], [3,3]])
p = np.array([2.5, 2])
import matplotlib.pyplot as plt
plt.plot(points[:,0], points[:,1], "ro")
plt.plot(p[0], p[1], "bo")

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 5, 10)
y = x**2
plt.plot(x,y);

# %%
x = np.linspace(0,10,20)
y=x**2.0
plt.plot(x,y, "bo-", linewidth=3, markersize=5);

# %%
plt.plot(x,y, "gs-", linewidth=1, markersize=3);

# %%
x = np.linspace(0,10,20)
y1=x**2.0
y2=x**1.5
plt.plot(x,y1, "bo-", linewidth=2, markersize=12, label="First")
plt.plot(x,y2, "gs-", linewidth=2, markersize=12, label="Second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left")
plt.savefig("mplot.pdf")

# %%
x = np.logspace(-1, 1, 20)
y1=x**2.0
y2=x**1.5
plt.plot(x,y1, "bo-", linewidth=2, markersize=5, label="First")
plt.plot(x,y2, "gs-", linewidth=2, markersize=5, label="Second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left")
plt.savefig("mplot.pdf")

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.standard_normal(size=1000)
plt.hist(x)
# Out:
# (array([  9.,  32.,  69., 142., 212., 206., 186.,  88.,  43.,  13.]),
#  array([-3.00068321, -2.42056034, -1.84043746, -1.26031459, -0.68019172,
#         -0.10006884,  0.48005403,  1.0601769 ,  1.64029978,  2.22042265,
#          2.80054552]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x, density=True)
# Out:
# (array([0.01551395, 0.05516073, 0.11894032, 0.24477573, 0.36543982,
#         0.35509719, 0.32062173, 0.151692  , 0.07412223, 0.02240905]),
#  array([-3.00068321, -2.42056034, -1.84043746, -1.26031459, -0.68019172,
#         -0.10006884,  0.48005403,  1.0601769 ,  1.64029978,  2.22042265,
#          2.80054552]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(1000)
plt.hist(x)
# Out:
# (array([  4.,  21.,  63., 172., 265., 235., 145.,  72.,  21.,   2.]),
#  array([-3.23028926, -2.57565087, -1.92101247, -1.26637408, -0.61173569,
#          0.0429027 ,  0.69754109,  1.35217949,  2.00681788,  2.66145627,
#          3.31609466]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.rand(30)
y = np.random.rand(30)
colors = np.random.rand(30)
shape = np.pi * (np.random.rand(30)*20) **2
plt.scatter(x, y, s=shape, c=colors, marker='H', alpha=0.7)
plt.show()
