# %% [markdown]
# <a href="https://colab.research.google.com/github/WooJungE/About_data/blob/main/20230321.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3
sqlite_file = '/content/drive/MyDrive/data/실습에 사용되는 파일2-20230314/boston.db'
conn = sqlite3.connect(sqlite_file)

df = pd.read_sql_query("select * from boston;", conn)
print("df.shape = " + str(df.shape))
df.set_index("record", inplace=True)
conn.close()
# Out:
# df.shape = (506, 15)

# %%
df.head()
# Out:
#            CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# record
# 0       0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1       0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2       0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3       0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4       0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#         PTRATIO       B  LSTAT  MEDV
# record
# 0          15.3  396.90   4.98  24.0
# 1          17.8  396.90   9.14  21.6
# 2          17.8  392.83   4.03  34.7
# 3          18.7  394.63   2.94  33.4
# 4          18.7  396.90   5.33  36.2

# %%
print(df.shape)
print(df.columns)
# Out:
# (506, 14)
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.describe()
print(df.describe().transpose())
# Out:
#          count        mean         std        min         25%        50%  \
# CRIM     506.0    3.593761    8.596783    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %%
df.max()
df.min()
df.mean()
print(df.median())
# Out:
# CRIM         0.25651
# ZN           0.00000
# INDUS        9.69000
# CHAS         0.00000
# NOX          0.53800
# RM           6.20850
# AGE         77.50000
# DIS          3.20745
# RAD          5.00000
# TAX        330.00000
# PTRATIO     19.05000
# B          391.44000
# LSTAT       11.36000
# MEDV        21.20000
# dtype: float64

# %%
df.idxmax()
print(df.idxmin())
# Out:
# CRIM         0
# ZN           1
# INDUS      195
# CHAS         0
# NOX        286
# RM         365
# AGE         41
# DIS        372
# RAD          0
# TAX        353
# PTRATIO    196
# B          450
# LSTAT      161
# MEDV       398
# dtype: int64

# %%
df.loc[0]
df.loc[2]
print(df.loc[0]['CRIM'])
# Out:
# 0.00632

# %%
df['AGE'].mean()
df['MEDV'].idxmax()
print(df['AGE'].idxmin())
# Out:
# 41

# %%
df.sort_values(by = 'ZN')
df.sort_values(by = 'ZN', ascending = False)
print(df.sort_values(by = 'ZN', ascending = False).head())
# Out:
#            CRIM     ZN  INDUS  CHAS     NOX     RM   AGE     DIS  RAD    TAX  \
# record
# 57      0.01432  100.0   1.32   0.0  0.4110  6.816  40.5  8.3248  5.0  256.0
# 204     0.02009   95.0   2.68   0.0  0.4161  8.034  31.9  5.1180  4.0  224.0
# 203     0.03510   95.0   2.68   0.0  0.4161  7.853  33.2  5.1180  4.0  224.0
# 200     0.01778   95.0   1.47   0.0  0.4030  7.135  13.9  7.6534  3.0  402.0
# 199     0.03150   95.0   1.47   0.0  0.4030  6.975  15.3  7.6534  3.0  402.0
#
#         PTRATIO       B  LSTAT  MEDV
# record
# 57         15.1  392.90   3.95  31.6
# 204        14.7  390.55   2.88  50.0
# 203        14.7  392.78   3.81  48.5
# 200        17.0  384.30   4.45  32.9
# 199        17.0  396.90   4.56  34.9

# %%
df.sort_values(by = 'ZN', inplace=True)
print(df.head())
# Out:
#            CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# record
# 505     0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
# 2       0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3       0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 5       0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0  222.0
# 13      0.62976  0.0   8.14   0.0  0.538  5.949  61.8  4.7075  4.0  307.0
#
#         PTRATIO       B  LSTAT  MEDV
# record
# 505        21.0  396.90   7.88  11.9
# 2          17.8  392.83   4.03  34.7
# 3          18.7  394.63   2.94  33.4
# 5          18.7  394.12   5.21  28.7
# 13         21.0  396.90   8.26  20.4

# %%
df.sort_values(by = 'record', inplace=True)
print(df.head())
# Out:
#            CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# record
# 0       0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1       0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2       0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3       0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4       0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#         PTRATIO       B  LSTAT  MEDV
# record
# 0          15.3  396.90   4.98  24.0
# 1          17.8  396.90   9.14  21.6
# 2          17.8  392.83   4.03  34.7
# 3          18.7  394.63   2.94  33.4
# 4          18.7  396.90   5.33  36.2

# %%
df[df.index % 2 == 0]
df[df['AGE']>95]
df[df['AGE']>95].describe().transpose()
# Out:
#          count        mean         std        min        25%        50%  \
# CRIM     111.0    9.131193   12.525663    0.09849    1.20826    5.87205
# ZN       111.0    0.585586    3.125317    0.00000    0.00000    0.00000
# INDUS    111.0   17.862342    4.606760    2.46000   18.10000   18.10000
# CHAS     111.0    0.063063    0.244179    0.00000    0.00000    0.00000
# NOX      111.0    0.664649    0.093411    0.44800    0.60500    0.65900
# RM       111.0    5.940144    0.712860    3.86300    5.49400    6.00600
# AGE      111.0   98.280180    1.657864   95.20000   96.95000   98.40000
# DIS      111.0    1.999828    0.873839    1.13700    1.52335    1.80260
# RAD      111.0   15.153153    9.832412    2.00000    5.00000   24.00000
# TAX      111.0  541.459459  156.998482  188.00000  403.00000  666.00000
# PTRATIO  111.0   19.127027    2.352868   13.00000   19.10000   20.20000
# B        111.0  335.421351  105.865712    2.60000  331.06500  383.29000
# ...

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("/content/drive/MyDrive/data/실습에 사용되는 파일2-20230314/iris.csv")

# %%
sns.scatterplot(x='petal length in cm', y ='petal width in cm', data=df, hue='species')
# Out:
# <Axes: xlabel='petal length in cm', ylabel='petal width in cm'>

# %%
sns.lmplot(x='petal length in cm', y ='petal width in cm', hue='species', data = df, fit_reg=False, palette='bright', markers=['o', 'x', 'v'])

# %%
sns.lmplot(x='petal length in cm', y ='petal width in cm', hue='species', data = df, palette='bright', markers=['o', 'x', 'v'])

# %%
penguins = sns.load_dataset("penguins")
sns.displot(data=penguins, x="flipper_length_mm")

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="kde")

# %%
sns.histplot(df['petal length in cm'])
# Out:
# <Axes: xlabel='petal length in cm', ylabel='Count'>

# %%
sns.histplot(df['petal length in cm'], bins=15)
# Out:
# <Axes: xlabel='petal length in cm', ylabel='Count'>

# %%
sns.jointplot(x='petal length in cm', y='petal width in cm', data=df, kind='scatter', marginal_kws=dict(bins=10))

# %%
sns.jointplot(x='petal length in cm', y = 'petal width in cm', data=df, kind='kde')

# %%
sns.violinplot(x='species', y='sepal width in cm', data = df)
# Out:
# <Axes: xlabel='species', ylabel='sepal width in cm'>

# %%
sns.violinplot(x='species', y='petal width in cm', data = df)
# Out:
# <Axes: xlabel='species', ylabel='petal width in cm'>

# %%
sns.pairplot(data=df)

# %%
import sqlite3
sqlite_file='/content/drive/MyDrive/data/실습에 사용되는 파일2-20230314/boston.db'
conn=sqlite3.connect(sqlite_file)
df = pd.read_sql_query("select *from boston;", conn)
vars_to_plot=['CRIM', 'AGE', 'DIS', 'LSTAT', 'MEDV']
sns.pairplot(data=df, vars=vars_to_plot)

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("/content/drive/MyDrive/data/실습에 사용되는 파일2-20230314/iris.csv")
sns.lmplot(x='sepal width in cm', y ='petal width in cm', hue='species', data=df, fit_reg=False, palette='bright', markers=['p','*','d'])
